# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## HW 5

# %% [markdown]
# ### Problem 1

# %%
size = 100000
bkgd = stats.norm.rvs(scale=3, size=size)
signal = stats.uniform.rvs(scale=18, size=size)
data = bkgd + signal

signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)

Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)

datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
plt.pcolormesh(datacenters,signalcenters,Psd.T)
plt.ylabel('True signal, $P(s|d)$', fontsize = 24)
plt.xlabel('Observed data, $P(d|s)$', fontsize = 24)
# Out:
# Text(0.5, 0, 'Observed data, $P(d|s)$')

# %% [markdown]
# ### Problem 1b

# %%
t = np.where((signal > 12.5) & (signal < 13))
plt.hist(data[t], bins = 25, density=True)
plt.title('Observed signal when true signal is chosen at 12.75')
plt.xlabel('Observed data')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# This histogram is the horiontal slice of the above 2D histogram when we select the true signal to be 12.75.

# %% [markdown]
# ### Problem 1c

# %%
t = np.where((data > 12.5) & (data < 13))
plt.hist(signal[t], bins = 25, density=True)
plt.title('True signal when observed signal is chosen at 12.75')
plt.xlabel('True data')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# This histogram is the vertical slice of the 2D histogram when the observed signal is chosen to be 12.75.

# %% [markdown]
# ### Problem 2

# %%
bkgd = stats.norm.rvs(loc=5, scale=3, size=size)
signal = stats.uniform.rvs(scale=18, size=size)
data = bkgd + signal
signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)
Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)
datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
plt.pcolormesh(datacenters,signalcenters,Psd.T)
plt.ylabel('True signal, $P(s|d)$', fontsize = 24)
plt.xlabel('Observed data, $P(d|s)$', fontsize = 24)
# Out:
# Text(0.5, 0, 'Observed data, $P(d|s)$')

# %%
t = np.where((signal > 12.5) & (signal < 13))
plt.hist(data[t], bins = 25, density=True)
plt.title('Observed signal when true signal is chosen at 12.75')
plt.xlabel('Observed data')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
t = np.where((data > 12.5) & (data < 13))
plt.hist(signal[t], bins = 25, density=True)
plt.title('True signal when observed signal is chosen at 12.75')
plt.xlabel('True data')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# The two are not centered at the saem value as we start with a background distribution that is not centered at zero, this adds a shift to any distributions that are created by injecting a signal to the background as we can see with our two histograms above.
